# %%
from pyspark import SparkConf, SparkContext
conf = SparkConf().setAppName("FilterQuiz")
sc = SparkContext.getOrCreate(conf=conf)

# %%
rdd = sc.textFile("/FileStore/tables/filter.txt")

# %%
rdd.collect()
# Out:
# Out[3]: ['this mango company animal',
#  'cat dog ant mic laptop',
#  'chair switch mobile am charger cover',
#  'amanda any alarm ant']

# %%
#remove  all the words that are starting from a or c
flatMappedRdd = rdd.flatMap(lambda x: x.split(' '))

# %%
flatMappedRdd.collect()
# Out:
# Out[5]: ['this',
#  'mango',
#  'company',
#  'animal',
#  'cat',
#  'dog',
#  'ant',
#  'mic',
#  'laptop',
#  'chair',
#  'switch',
#  'mobile',
#  'am',
#  'charger',
#  'cover',
#  'amanda',
#  'any',
#  'alarm',
#  'ant']

# %%
filteredRddLambda = flatMappedRdd.filter(lambda x: not (x.startswith('a') or x.startswith('c')) )

# %%
filteredRddLambda.collect()
# Out:
# Out[7]: ['this', 'mango', 'dog', 'mic', 'laptop', 'switch', 'mobile']

# %%
def filterAandC(x):
  if x.startswith('a') or x.startswith('c'):
    return False
  else:
    return True

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
