# %%
from pyspark import SparkConf, SparkContext
conf = SparkConf().setAppName("distinct")
sc = SparkContext.getOrCreate(conf=conf)

# %%
rdd = sc.textFile('/FileStore/tables/sample-3.txt')

# %%
rdd.collect()
# Out:
# Out[13]: ['10,20,30,62',
#  '58,69,64,87,52 ',
#  '85,965,257,35',
#  '25,36,78 ',
#  '25',
#  '25,56,58,',
#  '85,965,257,35',
#  '85,965,257,35',
#  '25,36,78 ',
#  '25,36,78 ',
#  '10,20,30,62']

# %%
rdd2 = rdd.distinct()

# %%
rdd2.collect()
# Out:
# Out[15]: ['10,20,30,62',
#  '58,69,64,87,52 ',
#  '85,965,257,35',
#  '25,36,78 ',
#  '25',
#  '25,56,58,']

# %%
rdd.count()
# Out:
# Out[16]: 11

# %%
rdd2.count()
# Out:
# Out[17]: 6

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
