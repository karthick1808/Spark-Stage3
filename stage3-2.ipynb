# %%
# Databricks notebook source
from pyspark import SparkConf, SparkContext
conf = SparkConf().setAppName("FlatMap")
sc = SparkContext.getOrCreate(conf=conf)

# %%
rdd = sc.textFile('/FileStore/tables/sample.txt')
rdd.collect()
# Out:
# Out[3]: ['10 20 30 62',
#  '58 69 64 87 52 ',
#  '85 965 257 35',
#  '25 36 78 ',
#  '25 ',
#  '25 56 58 ']

# %%
flatMappedRdd = rdd.flatMap(lambda x: x.split(" "))

# %%
flatMappedRdd.collect()
# Out:
# Out[5]: ['10',
#  '20',
#  '30',
#  '62',
#  '58',
#  '69',
#  '64',
#  '87',
#  '52',
#  '',
#  '85',
#  '965',
#  '257',
#  '35',
#  '25',
#  '36',
#  '78',
#  '',
#  '25',
#  '',
#  '25',
#  '56',
#  '58',
#  '']

# %%
rdd1 = sc.textFile('/FileStore/tables/sampletext.txt')

# %%
rdd2 = rdd1.flatMap(lambda x: x.split(" "))

# %%
rdd2.collect()
# Out:
# Out[9]: ['Hi', 'how', 'are', 'you?', 'Hope', 'you', 'are', 'doing', 'good', 'great']

# %%
rdd2.count()
# Out:
# Out[11]: 10

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
